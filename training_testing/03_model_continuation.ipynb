# %%
# ============================
# Imports
# ============================
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from torchvision import transforms as T
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import random
from PIL import Image, ImageOps


# ============================
# Dataset Classes
# ============================
class XBDMulticlassDataset(Dataset):
    def __init__(self, root_dir, transform_pre=None, transform_post=None,
                 image_size=(1024, 1024), tile_size=(256, 256), max_images=None):
        self.image_dir = os.path.join(root_dir, "images")
        self.mask_dir = os.path.join(root_dir, "masks")
        self.files = sorted([f for f in os.listdir(self.image_dir) if '_pre_disaster.png' in f])
        if max_images:
            self.files = self.files[:max_images]
        self.transform_pre = transform_pre
        self.transform_post = transform_post
        self.image_size = image_size
        self.tile_size = tile_size
        self.tiles_per_image = (image_size[0] // tile_size[0]) * (image_size[1] // tile_size[1])

    def __getitem__(self, idx, return_raw=False):
        pre_file = self.files[idx]
        post_file = pre_file.replace('pre', 'post')
        mask_file = post_file.replace('.png', '_rgb.png')
        pre_path = os.path.join(self.image_dir, pre_file)
        post_path = os.path.join(self.image_dir, post_file)
        mask_path = os.path.join(self.mask_dir, mask_file)

        pre_img_raw = Image.open(pre_path).convert("RGB").resize(self.image_size)
        post_img_raw = Image.open(post_path).convert("RGB").resize(self.image_size)
        mask_img_raw = Image.open(mask_path).convert("RGB").resize(self.image_size, Image.NEAREST)

        def optical_to_sar_like(img):
            img = img.convert('L')
            img = ImageOps.autocontrast(img, cutoff=2)
            return img

        def update_mask_multiclass(mask_rgb_img):
            mask_np = np.array(mask_rgb_img)
            label_mask = np.zeros(mask_np.shape[:2], dtype=np.uint8)
            color_to_label = {
                (0, 0, 0): 0, (0, 255, 255): 0, (0, 0, 255): 1,
                (255, 255, 0): 2, (255, 0, 0): 3, (211, 211, 211): 0
            }
            for rgb, label in color_to_label.items():
                mask = np.all(mask_np == rgb, axis=-1)
                label_mask[mask] = label
            return label_mask

        post_img_sar_raw = optical_to_sar_like(post_img_raw)
        if return_raw:
            mask_np = update_mask_multiclass(mask_img_raw)
            return pre_img_raw, post_img_sar_raw, mask_np

        pre_img = self.transform_pre(pre_img_raw) if self.transform_pre else pre_img_raw
        post_img_sar = self.transform_post(post_img_sar_raw) if self.transform_post else post_img_sar_raw

        input_tensor = torch.cat([pre_img, post_img_sar], dim=0)
        mask_tensor = torch.tensor(update_mask_multiclass(mask_img_raw), dtype=torch.long)

        return tile_tensor_and_mask(input_tensor, mask_tensor, self.tile_size)

    def __len__(self):
        return len(self.files)

    def get_tile_dataset(self):
        return TiledXBDDataset(self)

class TiledXBDDataset(Dataset):
    def __init__(self, parent_dataset):
        self.parent_dataset = parent_dataset
        self.tiles_per_image = parent_dataset.tiles_per_image

    def __getitem__(self, idx):
        image_idx = idx // self.tiles_per_image
        tile_idx = idx % self.tiles_per_image
        tiles_input, tiles_mask = self.parent_dataset[image_idx]
        return tiles_input[tile_idx], tiles_mask[tile_idx]

    def __len__(self):
        return len(self.parent_dataset) * self.tiles_per_image

class FilteredTileDataset(Dataset):
    def __init__(self, tiled_dataset, keep_zero_damage_prob=0.1):
        self.tiled_dataset = tiled_dataset
        self.filtered_indices = []
        for idx in range(len(tiled_dataset)):
            _, mask = tiled_dataset[idx]
            if mask.max() == 0:
                if random.random() < keep_zero_damage_prob:
                    self.filtered_indices.append(idx)
            else:
                self.filtered_indices.append(idx)

    def __len__(self):
        return len(self.filtered_indices)

    def __getitem__(self, idx):
        return self.tiled_dataset[self.filtered_indices[idx]]

# ============================
# Helper Functions
# ============================
def tile_tensor_and_mask(input_tensor, mask_tensor, tile_size=(256, 256)):
    C, H, W = input_tensor.shape
    th, tw = tile_size
    tiles_input, tiles_mask = [], []
    for i in range(0, H, th):
        for j in range(0, W, tw):
            tiles_input.append(input_tensor[:, i:i+th, j:j+tw])
            tiles_mask.append(mask_tensor[i:i+th, j:j+tw])
    return tiles_input, tiles_mask

# ============================
# Visualization
# ============================
def unnormalize(img_tensor, mean, std):
    for t, m, s in zip(img_tensor, mean, std):
        t.mul_(s).add_(m)
    return img_tensor

def visualize_predictions(inputs, masks, outputs, n=4):
    preds = torch.argmax(outputs, dim=1).cpu().numpy()
    masks = masks.cpu().numpy()
    cmap = mcolors.ListedColormap(['black', 'blue', 'yellow', 'red'])
    bounds = [0, 1, 2, 3, 4]
    norm = mcolors.BoundaryNorm(bounds, cmap.N)

    for i in range(min(n, inputs.shape[0])):
        fig, axs = plt.subplots(1, 3, figsize=(12, 4))
        pre_rgb = unnormalize(inputs[i][:3].clone(), [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        axs[0].imshow(np.transpose(torch.clamp(pre_rgb, 0, 1).cpu().numpy(), (1, 2, 0)))
        axs[0].set_title("Pre-disaster RGB")
        axs[0].axis('off')
        axs[1].imshow(inputs[i][3].cpu().numpy(), cmap='gray')
        axs[1].set_title("Post-disaster SAR")
        axs[1].axis('off')
        axs[2].imshow(preds[i], cmap=cmap, norm=norm)
        axs[2].set_title("Predicted")
        axs[2].axis('off')
        plt.show()
        plt.figure()
        plt.imshow(masks[i], cmap=cmap, norm=norm)
        plt.title("Ground Truth")
        plt.axis('off')
        plt.show()

print("Saved all")
# Out:
# Saved all

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class UNetOriginal(nn.Module):
    def __init__(self, in_channels=4, out_classes=4):
        super().__init__()

        def conv_block(in_c, out_c):
            return nn.Sequential(
                nn.Conv2d(in_c, out_c, kernel_size=3, padding=1),
                nn.BatchNorm2d(out_c),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_c, out_c, kernel_size=3, padding=1),
                nn.BatchNorm2d(out_c),
                nn.ReLU(inplace=True)
            )

        # Encoder
        self.enc1 = conv_block(in_channels, 64)
        self.enc2 = conv_block(64, 128)
        self.enc3 = conv_block(128, 256)
        self.enc4 = conv_block(256, 512)

        self.pool = nn.MaxPool2d(2)

        # Bottleneck
        self.bottleneck = conv_block(512, 1024)

        # Decoder
        self.up4 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.dec4 = conv_block(1024, 512)

        self.up3 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.dec3 = conv_block(512, 256)

        self.up2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec2 = conv_block(256, 128)

        self.up1 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec1 = conv_block(128, 64)

        # Output
        self.final = nn.Conv2d(64, out_classes, kernel_size=1)

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))

        b = self.bottleneck(self.pool(e4))

        d4 = self.dec4(torch.cat([self.up4(b), e4], dim=1))
        d3 = self.dec3(torch.cat([self.up3(d4), e3], dim=1))
        d2 = self.dec2(torch.cat([self.up2(d3), e2], dim=1))
        d1 = self.dec1(torch.cat([self.up1(d2), e1], dim=1))

        return self.final(d1)
model_path = 'C:/Users/sweta/anaconda_projects/non-trivial/performance_bias/iteration_models/model_epoch7.pt'
model = UNetOriginal(in_channels=4, out_classes=4)
model.load_state_dict(torch.load(model_path, map_location='cpu'))
model.eval()
print("model loaded successfully")
# Out:
# model loaded successfully
# C:\Users\sweta\AppData\Local\Temp\ipykernel_10684\496959142.py:62: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location='cpu'))

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms as T
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import random
from PIL import Image, ImageOps
import csv

# ============================
# Dataset Classes and Helpers
# ============================

class XBDMulticlassDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, transform_pre=None, transform_post=None,
                 image_size=(1024, 1024), tile_size=(256, 256), max_images=None):
        self.image_dir = os.path.join(root_dir, "images")
        self.mask_dir = os.path.join(root_dir, "masks")
        self.files = sorted([f for f in os.listdir(self.image_dir) if '_pre_disaster.png' in f])
        if max_images:
            self.files = self.files[:max_images]
        self.transform_pre = transform_pre
        self.transform_post = transform_post
        self.image_size = image_size
        self.tile_size = tile_size
        self.tiles_per_image = (image_size[0] // tile_size[0]) * (image_size[1] // tile_size[1])

    def __getitem__(self, idx, return_raw=False):
        pre_file = self.files[idx]
        post_file = pre_file.replace('pre', 'post')
        mask_file = post_file.replace('.png', '_rgb.png')
        pre_path = os.path.join(self.image_dir, pre_file)
        post_path = os.path.join(self.image_dir, post_file)
        mask_path = os.path.join(self.mask_dir, mask_file)

        pre_img_raw = Image.open(pre_path).convert("RGB").resize(self.image_size)
        post_img_raw = Image.open(post_path).convert("RGB").resize(self.image_size)
        mask_img_raw = Image.open(mask_path).convert("RGB").resize(self.image_size, Image.NEAREST)

        def optical_to_sar_like(img):
            img = img.convert('L')
            img = ImageOps.autocontrast(img, cutoff=2)
            return img

        def update_mask_multiclass(mask_rgb_img):
            mask_np = np.array(mask_rgb_img)
            label_mask = np.zeros(mask_np.shape[:2], dtype=np.uint8)
            color_to_label = {
                (0, 0, 0): 0, (0, 255, 255): 0, (0, 0, 255): 1,
                (255, 255, 0): 2, (255, 0, 0): 3, (211, 211, 211): 0
            }
            for rgb, label in color_to_label.items():
                mask = np.all(mask_np == rgb, axis=-1)
                label_mask[mask] = label
            return label_mask

        post_img_sar_raw = optical_to_sar_like(post_img_raw)
        if return_raw:
            mask_np = update_mask_multiclass(mask_img_raw)
            return pre_img_raw, post_img_sar_raw, mask_np

        pre_img = self.transform_pre(pre_img_raw) if self.transform_pre else pre_img_raw
        post_img_sar = self.transform_post(post_img_sar_raw) if self.transform_post else post_img_sar_raw

        input_tensor = torch.cat([pre_img, post_img_sar], dim=0)
        mask_tensor = torch.tensor(update_mask_multiclass(mask_img_raw), dtype=torch.long)

        return tile_tensor_and_mask(input_tensor, mask_tensor, self.tile_size)

    def __len__(self):
        return len(self.files)

    def get_tile_dataset(self):
        return TiledXBDDataset(self)

class TiledXBDDataset(torch.utils.data.Dataset):
    def __init__(self, parent_dataset):
        self.parent_dataset = parent_dataset
        self.tiles_per_image = parent_dataset.tiles_per_image

    def __getitem__(self, idx):
        image_idx = idx // self.tiles_per_image
        tile_idx = idx % self.tiles_per_image
        tiles_input, tiles_mask = self.parent_dataset[image_idx]
        return tiles_input[tile_idx], tiles_mask[tile_idx]

    def __len__(self):
        return len(self.parent_dataset) * self.tiles_per_image

class FilteredTileDataset(torch.utils.data.Dataset):
    def __init__(self, dataset, keep_zero_damage_prob=0.1):
        """
        Filters full-size images from dataset before tiling to avoid unnecessary computation.
        """
        self.dataset = dataset  # this should be an XBDMulticlassDataset, not a tiled one
        self.valid_image_indices = []

        print("Filtering full images before tiling...")

        for idx in range(len(dataset)):
            if idx % 100 == 0:
                print(f"Checking image {idx}/{len(dataset)}")

            _, _, mask = dataset.__getitem__(idx, return_raw=True)
            if mask.max() == 0:
                if random.random() < keep_zero_damage_prob:
                    self.valid_image_indices.append(idx)
            else:
                self.valid_image_indices.append(idx)

        print(f"Kept {len(self.valid_image_indices)} of {len(dataset)} images after filtering.")
        self.tiles_per_image = dataset.tiles_per_image
        self.total_tiles = len(self.valid_image_indices) * self.tiles_per_image

    def __len__(self):
        return self.total_tiles

    def __getitem__(self, idx):
        image_idx = self.valid_image_indices[idx // self.tiles_per_image]
        tile_idx = idx % self.tiles_per_image
        tiles_input, tiles_mask = self.dataset[image_idx]
        return tiles_input[tile_idx], tiles_mask[tile_idx]


def tile_tensor_and_mask(input_tensor, mask_tensor, tile_size=(256, 256)):
    C, H, W = input_tensor.shape
    th, tw = tile_size
    tiles_input, tiles_mask = [], []
    for i in range(0, H, th):
        for j in range(0, W, tw):
            tiles_input.append(input_tensor[:, i:i+th, j:j+tw])
            tiles_mask.append(mask_tensor[i:i+th, j:j+tw])
    return tiles_input, tiles_mask

def unnormalize(img_tensor, mean, std):
    for t, m, s in zip(img_tensor, mean, std):
        t.mul_(s).add_(m)
    return img_tensor

def visualize_predictions(inputs, masks, outputs, n=4):
    preds = torch.argmax(outputs, dim=1).cpu().numpy()
    masks = masks.cpu().numpy()
    cmap = mcolors.ListedColormap(['black', 'blue', 'yellow', 'red'])
    bounds = [0, 1, 2, 3, 4]
    norm = mcolors.BoundaryNorm(bounds, cmap.N)

    for i in range(min(n, inputs.shape[0])):
        fig, axs = plt.subplots(1, 3, figsize=(12, 4))
        pre_rgb = unnormalize(inputs[i][:3].clone(), [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        axs[0].imshow(np.transpose(torch.clamp(pre_rgb, 0, 1).cpu().numpy(), (1, 2, 0)))
        axs[0].set_title("Pre-disaster RGB")
        axs[0].axis('off')
        axs[1].imshow(inputs[i][3].cpu().numpy(), cmap='gray')
        axs[1].set_title("Post-disaster SAR")
        axs[1].axis('off')
        axs[2].imshow(preds[i], cmap=cmap, norm=norm)
        axs[2].set_title("Predicted")
        axs[2].axis('off')
        plt.show()
        plt.figure()
        plt.imshow(masks[i], cmap=cmap, norm=norm)
        plt.title("Ground Truth")
        plt.axis('off')
        plt.show()
import matplotlib.pyplot as plt

def save_visual_predictions(inputs, masks, outputs, epoch, visuals_path, n=30):
    preds = torch.argmax(outputs, dim=1).cpu().numpy()
    masks_np = masks.cpu().numpy()
    
    cmap = mcolors.ListedColormap(['black', 'blue', 'yellow', 'red'])
    bounds = [0, 1, 2, 3, 4]
    norm = mcolors.BoundaryNorm(bounds, cmap.N)

    for i in range(min(n, inputs.shape[0])):
        fig, axs = plt.subplots(1, 4, figsize=(16, 4))  # 4 subplots now

        # Pre-disaster RGB
        pre_rgb = unnormalize(inputs[i][:3].clone(), [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        axs[0].imshow(np.transpose(torch.clamp(pre_rgb, 0, 1).cpu().numpy(), (1, 2, 0)))
        axs[0].set_title("Pre-disaster RGB")
        axs[0].axis('off')

        # Post-disaster SAR
        axs[1].imshow(inputs[i][3].cpu().numpy(), cmap='gray')
        axs[1].set_title("Post-disaster SAR")
        axs[1].axis('off')

        # Predicted mask
        axs[2].imshow(preds[i], cmap=cmap, norm=norm)
        axs[2].set_title("Predicted")
        axs[2].axis('off')

        # Ground truth mask
        axs[3].imshow(masks_np[i], cmap=cmap, norm=norm)
        axs[3].set_title("Ground Truth")
        axs[3].axis('off')

        fig_path = os.path.join(visuals_path, f'epoch{epoch}_sample{i}.png')
        plt.savefig(fig_path, bbox_inches='tight')
        plt.close(fig)  # Close to free memory

print("Dataset and helper functions loaded")

# ============================
# Model training + metrics + visualization
# ============================

# Define your model class or import it here
# from your_model_file import UNetOriginal

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Model & optimizer
model = UNetOriginal(in_channels=4, out_classes=4).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()

# Transforms
transform_pre = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
transform_post = T.Compose([
    T.ToTensor(),
    T.Normalize(mean=[0.5], std=[0.5])
])

data_root = r"C:\Users\sweta\.cache\kagglehub\datasets\qianlanzz\xbd-dataset\versions\1\xbd\tier1"
print("Loading dataset from:", data_root)

dataset = XBDMulticlassDataset(
    data_root,
    transform_pre=transform_pre,
    transform_post=transform_post,
    image_size=(1024, 1024),
    tile_size=(256, 256),
)

print(f"Loaded XBDMulticlassDataset with {len(dataset)} images")

filtered_dataset = FilteredTileDataset(dataset, keep_zero_damage_prob=0.1)
print(f"Filtered tiled dataset has {len(filtered_dataset)} tiles after zero-damage filtering")


train_loader = DataLoader(filtered_dataset, batch_size=8, shuffle=True, num_workers=0)
print("DataLoader created")

checkpoint_path = 'C:/Users/sweta/anaconda_projects/non-trivial/performance_bias/iteration_models/model_epoch7.pt'
if os.path.exists(checkpoint_path):
    print(f"Loading checkpoint from {checkpoint_path} ...")
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint)  # checkpoint is state_dict only
    print("Checkpoint loaded. Model weights restored.")
    start_epoch = 8
else:
    print("No checkpoint found, starting from scratch")
    start_epoch = 0

num_epochs = 15  # total epochs

metrics_csv_path = r'C:/Users/sweta/anaconda_projects/non-trivial/performance_bias/iteration_models/metrics_log.csv'
visuals_path = r'C:/Users/sweta/anaconda_projects/non-trivial/performance_bias/iteration_models/visuals' #this is a folder

def compute_iou_per_class(preds, labels, num_classes=4):
    ious = []
    preds = preds.flatten()
    labels = labels.flatten()
    for cls in range(num_classes):
        pred_inds = preds == cls
        label_inds = labels == cls
        intersection = np.logical_and(pred_inds, label_inds).sum()
        union = np.logical_or(pred_inds, label_inds).sum()
        iou = intersection / union if union > 0 else 1.0
        ious.append(iou)
    return ious

def compute_dice_per_class(preds, labels, num_classes=4):
    dices = []
    preds = preds.flatten()
    labels = labels.flatten()
    for cls in range(num_classes):
        pred_inds = preds == cls
        label_inds = labels == cls
        intersection = 2 * np.logical_and(pred_inds, label_inds).sum()
        denominator = pred_inds.sum() + label_inds.sum()
        dice = intersection / denominator if denominator > 0 else 1.0
        dices.append(dice)
    return dices

for epoch in range(start_epoch, num_epochs):
    print(f"\n======== Epoch {epoch} ========")
    model.train()
    total_loss = 0
    for batch_idx, (inputs, masks) in enumerate(train_loader):
        print(f"Batch {batch_idx} - Loading data...")
        inputs, masks = inputs.to(device), masks.to(device)
        print(f"Batch {batch_idx} - Inputs shape: {inputs.shape}, Masks shape: {masks.shape}")

        optimizer.zero_grad()
        outputs = model(inputs)
        print(f"Batch {batch_idx} - Forward pass done. Outputs shape: {outputs.shape}")

        loss = criterion(outputs, masks)
        print(f"Batch {batch_idx} - Loss computed: {loss.item():.6f}")

        loss.backward()
        optimizer.step()
        print(f"Batch {batch_idx} - Backward pass and optimizer step done")

        total_loss += loss.item()

        if batch_idx % 10 == 0:
            print(f"Epoch {epoch} Batch {batch_idx} Loss: {loss.item():.6f}")

    avg_loss = total_loss / len(train_loader)
    print(f"Epoch {epoch} Average Loss: {avg_loss:.6f}")

    # Save checkpoint
    checkpoint_file = f'model_epoch{epoch}.pt'
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }, checkpoint_file)
    print(f"Checkpoint saved: {checkpoint_file}")

    # Evaluate on entire filtered_dataset for metrics
    model.eval()
    print("Evaluating on entire filtered dataset for metrics...")
    all_preds = []
    all_masks = []

    with torch.no_grad():
        filtered_loader_eval = DataLoader(filtered_dataset, batch_size=8, shuffle=False, num_workers=0)
        for batch_idx_eval, (inputs_eval, masks_eval) in enumerate(filtered_loader_eval):
            inputs_eval, masks_eval = inputs_eval.to(device), masks_eval.to(device)
            outputs_eval = model(inputs_eval)
            preds_eval = torch.argmax(outputs_eval, dim=1).cpu().numpy()
            masks_eval_np = masks_eval.cpu().numpy()

            all_preds.append(preds_eval)
            all_masks.append(masks_eval_np)

    all_preds_np = np.concatenate(all_preds, axis=0)
    all_masks_np = np.concatenate(all_masks, axis=0)

    ious = compute_iou_per_class(all_preds_np, all_masks_np)
    dices = compute_dice_per_class(all_preds_np, all_masks_np)
    print(f"Epoch {epoch} IoU per class: {ious}")
    print(f"Epoch {epoch} Dice per class: {dices}")

    # Append metrics to CSV
    file_exists = os.path.isfile(metrics_csv_path)
    with open(metrics_csv_path, 'a', newline='') as f:
        writer = csv.writer(f)
        if not file_exists:
            print(f"Creating new metrics CSV at {metrics_csv_path}")
            writer.writerow(['epoch',
                             'iou_class_0', 'iou_class_1', 'iou_class_2', 'iou_class_3',
                             'dice_class_0', 'dice_class_1', 'dice_class_2', 'dice_class_3'])
        writer.writerow([epoch] + ious + dices)
        print(f"Logged metrics for epoch {epoch} to CSV")

    # Visualize predictions on a small batch
    with torch.no_grad():
        print("Saving visual predictions on a sample batch...")
        inputs_viz, masks_viz = next(iter(train_loader))
        inputs_viz, masks_viz = inputs_viz.to(device), masks_viz.to(device)
        outputs_viz = model(inputs_viz)
        save_visual_predictions(inputs_viz, masks_viz, outputs_viz, epoch, visuals_path, n=15)

    print(f"Epoch {epoch} complete\n")
# Out:
# Dataset and helper functions loaded
# Using device: cpu
# Loading dataset from: C:\Users\sweta\.cache\kagglehub\datasets\qianlanzz\xbd-dataset\versions\1\xbd\tier1
# Loaded XBDMulticlassDataset with 2799 images
# Filtering full images before tiling...
# Checking image 0/2799
# Checking image 100/2799
# Checking image 200/2799
# Checking image 300/2799
# Checking image 400/2799
# Checking image 500/2799
# Checking image 600/2799
# Checking image 700/2799
# Checking image 800/2799
# Checking image 900/2799
# Checking image 1000/2799
# Checking image 1100/2799
# Checking image 1200/2799
# Checking image 1300/2799
# Checking image 1400/2799
# Checking image 1500/2799
# Checking image 1600/2799
# Checking image 1700/2799
# Checking image 1800/2799
# Checking image 1900/2799
# Checking image 2000/2799
# Checking image 2100/2799
# Checking image 2200/2799
# Checking image 2300/2799
# Checking image 2400/2799
# Checking image 2500/2799
# Checking image 2600/2799
# Checking image 2700/2799
# Kept 1476 of 2799 images after filtering.
# Filtered tiled dataset has 23616 tiles after zero-damage filtering
# DataLoader created
# Loading checkpoint from C:/Users/sweta/anaconda_projects/non-trivial/performance_bias/iteration_models/model_epoch7.pt ...
# Checkpoint loaded. Model weights restored.
#
# ======== Epoch 8 ========
# C:\Users\sweta\AppData\Local\Temp\ipykernel_10684\1559230455.py:257: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# Batch 0 - Loading data...
# Batch 0 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 0 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 0 - Loss computed: 0.026508
# Batch 0 - Backward pass and optimizer step done
# Epoch 8 Batch 0 Loss: 0.026508
# Batch 1 - Loading data...
# Batch 1 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 1 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 1 - Loss computed: 0.063511
# Batch 1 - Backward pass and optimizer step done
# Batch 2 - Loading data...
# Batch 2 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2 - Loss computed: 0.028944
# Batch 2 - Backward pass and optimizer step done
# Batch 3 - Loading data...
# Batch 3 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 3 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 3 - Loss computed: 0.014283
# Batch 3 - Backward pass and optimizer step done
# Batch 4 - Loading data...
# Batch 4 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 4 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 4 - Loss computed: 0.049674
# Batch 4 - Backward pass and optimizer step done
# Batch 5 - Loading data...
# Batch 5 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 5 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 5 - Loss computed: 0.058516
# Batch 5 - Backward pass and optimizer step done
# Batch 6 - Loading data...
# Batch 6 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 6 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 6 - Loss computed: 0.025059
# Batch 6 - Backward pass and optimizer step done
# Batch 7 - Loading data...
# Batch 7 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 7 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 7 - Loss computed: 0.022577
# Batch 7 - Backward pass and optimizer step done
# Batch 8 - Loading data...
# Batch 8 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 8 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 8 - Loss computed: 0.041306
# Batch 8 - Backward pass and optimizer step done
# Batch 9 - Loading data...
# Batch 9 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 9 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 9 - Loss computed: 0.012619
# Batch 9 - Backward pass and optimizer step done
# Batch 10 - Loading data...
# Batch 10 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 10 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 10 - Loss computed: 0.070264
# Batch 10 - Backward pass and optimizer step done
# Epoch 8 Batch 10 Loss: 0.070264
# Batch 11 - Loading data...
# Batch 11 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 11 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 11 - Loss computed: 0.046297
# Batch 11 - Backward pass and optimizer step done
# Batch 12 - Loading data...
# Batch 12 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 12 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 12 - Loss computed: 0.199658
# Batch 12 - Backward pass and optimizer step done
# Batch 13 - Loading data...
# Batch 13 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 13 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 13 - Loss computed: 0.027513
# Batch 13 - Backward pass and optimizer step done
# Batch 14 - Loading data...
# Batch 14 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 14 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 14 - Loss computed: 0.038230
# Batch 14 - Backward pass and optimizer step done
# Batch 15 - Loading data...
# Batch 15 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 15 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 15 - Loss computed: 0.026343
# Batch 15 - Backward pass and optimizer step done
# Batch 16 - Loading data...
# Batch 16 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 16 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 16 - Loss computed: 0.091501
# Batch 16 - Backward pass and optimizer step done
# Batch 17 - Loading data...
# Batch 17 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 17 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 17 - Loss computed: 0.042901
# Batch 17 - Backward pass and optimizer step done
# Batch 18 - Loading data...
# Batch 18 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 18 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 18 - Loss computed: 0.041574
# Batch 18 - Backward pass and optimizer step done
# Batch 19 - Loading data...
# Batch 19 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 19 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 19 - Loss computed: 0.016197
# Batch 19 - Backward pass and optimizer step done
# Batch 20 - Loading data...
# Batch 20 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 20 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 20 - Loss computed: 0.034410
# Batch 20 - Backward pass and optimizer step done
# Epoch 8 Batch 20 Loss: 0.034410
# Batch 21 - Loading data...
# Batch 21 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 21 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 21 - Loss computed: 0.058904
# Batch 21 - Backward pass and optimizer step done
# Batch 22 - Loading data...
# Batch 22 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 22 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 22 - Loss computed: 0.054589
# Batch 22 - Backward pass and optimizer step done
# Batch 23 - Loading data...
# Batch 23 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 23 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 23 - Loss computed: 0.069598
# Batch 23 - Backward pass and optimizer step done
# Batch 24 - Loading data...
# Batch 24 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 24 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 24 - Loss computed: 0.055075
# Batch 24 - Backward pass and optimizer step done
# Batch 25 - Loading data...
# Batch 25 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 25 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 25 - Loss computed: 0.060320
# Batch 25 - Backward pass and optimizer step done
# Batch 26 - Loading data...
# Batch 26 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 26 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 26 - Loss computed: 0.024763
# Batch 26 - Backward pass and optimizer step done
# Batch 27 - Loading data...
# Batch 27 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 27 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 27 - Loss computed: 0.064807
# Batch 27 - Backward pass and optimizer step done
# Batch 28 - Loading data...
# Batch 28 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 28 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 28 - Loss computed: 0.044219
# Batch 28 - Backward pass and optimizer step done
# Batch 29 - Loading data...
# Batch 29 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 29 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 29 - Loss computed: 0.033409
# Batch 29 - Backward pass and optimizer step done
# Batch 30 - Loading data...
# Batch 30 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 30 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 30 - Loss computed: 0.026919
# Batch 30 - Backward pass and optimizer step done
# Epoch 8 Batch 30 Loss: 0.026919
# Batch 31 - Loading data...
# Batch 31 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 31 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 31 - Loss computed: 0.042530
# Batch 31 - Backward pass and optimizer step done
# Batch 32 - Loading data...
# Batch 32 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 32 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 32 - Loss computed: 0.049428
# Batch 32 - Backward pass and optimizer step done
# Batch 33 - Loading data...
# Batch 33 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 33 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 33 - Loss computed: 0.054959
# Batch 33 - Backward pass and optimizer step done
# Batch 34 - Loading data...
# Batch 34 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 34 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 34 - Loss computed: 0.051181
# Batch 34 - Backward pass and optimizer step done
# Batch 35 - Loading data...
# Batch 35 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 35 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 35 - Loss computed: 0.035652
# Batch 35 - Backward pass and optimizer step done
# Batch 36 - Loading data...
# Batch 36 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 36 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 36 - Loss computed: 0.029013
# Batch 36 - Backward pass and optimizer step done
# Batch 37 - Loading data...
# Batch 37 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 37 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 37 - Loss computed: 0.026412
# Batch 37 - Backward pass and optimizer step done
# Batch 38 - Loading data...
# Batch 38 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 38 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 38 - Loss computed: 0.036607
# Batch 38 - Backward pass and optimizer step done
# Batch 39 - Loading data...
# Batch 39 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 39 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 39 - Loss computed: 0.049065
# Batch 39 - Backward pass and optimizer step done
# Batch 40 - Loading data...
# Batch 40 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 40 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 40 - Loss computed: 0.024693
# Batch 40 - Backward pass and optimizer step done
# Epoch 8 Batch 40 Loss: 0.024693
# Batch 41 - Loading data...
# Batch 41 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 41 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 41 - Loss computed: 0.016674
# Batch 41 - Backward pass and optimizer step done
# Batch 42 - Loading data...
# Batch 42 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 42 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 42 - Loss computed: 0.093777
# Batch 42 - Backward pass and optimizer step done
# Batch 43 - Loading data...
# Batch 43 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 43 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 43 - Loss computed: 0.017234
# Batch 43 - Backward pass and optimizer step done
# Batch 44 - Loading data...
# Batch 44 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 44 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 44 - Loss computed: 0.018783
# Batch 44 - Backward pass and optimizer step done
# Batch 45 - Loading data...
# Batch 45 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 45 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 45 - Loss computed: 0.435347
# Batch 45 - Backward pass and optimizer step done
# Batch 46 - Loading data...
# Batch 46 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 46 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 46 - Loss computed: 0.021733
# Batch 46 - Backward pass and optimizer step done
# Batch 47 - Loading data...
# Batch 47 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 47 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 47 - Loss computed: 0.016725
# Batch 47 - Backward pass and optimizer step done
# Batch 48 - Loading data...
# Batch 48 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 48 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 48 - Loss computed: 0.025926
# Batch 48 - Backward pass and optimizer step done
# Batch 49 - Loading data...
# Batch 49 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 49 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 49 - Loss computed: 0.028254
# Batch 49 - Backward pass and optimizer step done
# Batch 50 - Loading data...
# Batch 50 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 50 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 50 - Loss computed: 0.024614
# Batch 50 - Backward pass and optimizer step done
# Epoch 8 Batch 50 Loss: 0.024614
# Batch 51 - Loading data...
# Batch 51 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 51 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 51 - Loss computed: 0.050052
# Batch 51 - Backward pass and optimizer step done
# Batch 52 - Loading data...
# Batch 52 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 52 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 52 - Loss computed: 0.035631
# Batch 52 - Backward pass and optimizer step done
# Batch 53 - Loading data...
# Batch 53 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 53 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 53 - Loss computed: 0.035137
# Batch 53 - Backward pass and optimizer step done
# Batch 54 - Loading data...
# Batch 54 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 54 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 54 - Loss computed: 0.011507
# Batch 54 - Backward pass and optimizer step done
# Batch 55 - Loading data...
# Batch 55 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 55 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 55 - Loss computed: 0.040487
# Batch 55 - Backward pass and optimizer step done
# Batch 56 - Loading data...
# Batch 56 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 56 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 56 - Loss computed: 0.066567
# Batch 56 - Backward pass and optimizer step done
# Batch 57 - Loading data...
# Batch 57 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 57 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 57 - Loss computed: 0.102314
# Batch 57 - Backward pass and optimizer step done
# Batch 58 - Loading data...
# Batch 58 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 58 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 58 - Loss computed: 0.014944
# Batch 58 - Backward pass and optimizer step done
# Batch 59 - Loading data...
# Batch 59 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 59 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 59 - Loss computed: 0.095117
# Batch 59 - Backward pass and optimizer step done
# Batch 60 - Loading data...
# Batch 60 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 60 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 60 - Loss computed: 0.017492
# Batch 60 - Backward pass and optimizer step done
# Epoch 8 Batch 60 Loss: 0.017492
# Batch 61 - Loading data...
# Batch 61 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 61 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 61 - Loss computed: 0.056565
# Batch 61 - Backward pass and optimizer step done
# Batch 62 - Loading data...
# Batch 62 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 62 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 62 - Loss computed: 0.023364
# Batch 62 - Backward pass and optimizer step done
# Batch 63 - Loading data...
# Batch 63 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 63 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 63 - Loss computed: 0.095723
# Batch 63 - Backward pass and optimizer step done
# Batch 64 - Loading data...
# Batch 64 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 64 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 64 - Loss computed: 0.056918
# Batch 64 - Backward pass and optimizer step done
# Batch 65 - Loading data...
# Batch 65 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 65 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 65 - Loss computed: 0.028164
# Batch 65 - Backward pass and optimizer step done
# Batch 66 - Loading data...
# Batch 66 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 66 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 66 - Loss computed: 0.015182
# Batch 66 - Backward pass and optimizer step done
# Batch 67 - Loading data...
# Batch 67 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 67 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 67 - Loss computed: 0.044003
# Batch 67 - Backward pass and optimizer step done
# Batch 68 - Loading data...
# Batch 68 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 68 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 68 - Loss computed: 0.205509
# Batch 68 - Backward pass and optimizer step done
# Batch 69 - Loading data...
# Batch 69 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 69 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 69 - Loss computed: 0.078617
# Batch 69 - Backward pass and optimizer step done
# Batch 70 - Loading data...
# Batch 70 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 70 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 70 - Loss computed: 0.044072
# Batch 70 - Backward pass and optimizer step done
# Epoch 8 Batch 70 Loss: 0.044072
# Batch 71 - Loading data...
# Batch 71 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 71 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 71 - Loss computed: 0.086153
# Batch 71 - Backward pass and optimizer step done
# Batch 72 - Loading data...
# Batch 72 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 72 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 72 - Loss computed: 0.027371
# Batch 72 - Backward pass and optimizer step done
# Batch 73 - Loading data...
# Batch 73 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 73 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 73 - Loss computed: 0.038350
# Batch 73 - Backward pass and optimizer step done
# Batch 74 - Loading data...
# Batch 74 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 74 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 74 - Loss computed: 0.024053
# Batch 74 - Backward pass and optimizer step done
# Batch 75 - Loading data...
# Batch 75 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 75 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 75 - Loss computed: 0.082512
# Batch 75 - Backward pass and optimizer step done
# Batch 76 - Loading data...
# Batch 76 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 76 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 76 - Loss computed: 0.068840
# Batch 76 - Backward pass and optimizer step done
# Batch 77 - Loading data...
# Batch 77 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 77 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 77 - Loss computed: 0.027645
# Batch 77 - Backward pass and optimizer step done
# Batch 78 - Loading data...
# Batch 78 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 78 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 78 - Loss computed: 0.145971
# Batch 78 - Backward pass and optimizer step done
# Batch 79 - Loading data...
# Batch 79 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 79 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 79 - Loss computed: 0.026141
# Batch 79 - Backward pass and optimizer step done
# Batch 80 - Loading data...
# Batch 80 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 80 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 80 - Loss computed: 0.035628
# Batch 80 - Backward pass and optimizer step done
# Epoch 8 Batch 80 Loss: 0.035628
# Batch 81 - Loading data...
# Batch 81 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 81 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 81 - Loss computed: 0.024009
# Batch 81 - Backward pass and optimizer step done
# Batch 82 - Loading data...
# Batch 82 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 82 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 82 - Loss computed: 0.022888
# Batch 82 - Backward pass and optimizer step done
# Batch 83 - Loading data...
# Batch 83 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 83 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 83 - Loss computed: 0.017470
# Batch 83 - Backward pass and optimizer step done
# Batch 84 - Loading data...
# Batch 84 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 84 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 84 - Loss computed: 0.021957
# Batch 84 - Backward pass and optimizer step done
# Batch 85 - Loading data...
# Batch 85 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 85 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 85 - Loss computed: 0.035609
# Batch 85 - Backward pass and optimizer step done
# Batch 86 - Loading data...
# Batch 86 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 86 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 86 - Loss computed: 0.019123
# Batch 86 - Backward pass and optimizer step done
# Batch 87 - Loading data...
# Batch 87 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 87 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 87 - Loss computed: 0.015021
# Batch 87 - Backward pass and optimizer step done
# Batch 88 - Loading data...
# Batch 88 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 88 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 88 - Loss computed: 0.003910
# Batch 88 - Backward pass and optimizer step done
# Batch 89 - Loading data...
# Batch 89 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 89 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 89 - Loss computed: 0.006610
# Batch 89 - Backward pass and optimizer step done
# Batch 90 - Loading data...
# Batch 90 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 90 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 90 - Loss computed: 0.014651
# Batch 90 - Backward pass and optimizer step done
# Epoch 8 Batch 90 Loss: 0.014651
# Batch 91 - Loading data...
# Batch 91 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 91 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 91 - Loss computed: 0.016858
# Batch 91 - Backward pass and optimizer step done
# Batch 92 - Loading data...
# Batch 92 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 92 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 92 - Loss computed: 0.016963
# Batch 92 - Backward pass and optimizer step done
# Batch 93 - Loading data...
# Batch 93 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 93 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 93 - Loss computed: 0.012402
# Batch 93 - Backward pass and optimizer step done
# Batch 94 - Loading data...
# Batch 94 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 94 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 94 - Loss computed: 0.091206
# Batch 94 - Backward pass and optimizer step done
# Batch 95 - Loading data...
# Batch 95 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 95 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 95 - Loss computed: 0.046411
# Batch 95 - Backward pass and optimizer step done
# Batch 96 - Loading data...
# Batch 96 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 96 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 96 - Loss computed: 0.009627
# Batch 96 - Backward pass and optimizer step done
# Batch 97 - Loading data...
# Batch 97 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 97 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 97 - Loss computed: 0.018926
# Batch 97 - Backward pass and optimizer step done
# Batch 98 - Loading data...
# Batch 98 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 98 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 98 - Loss computed: 0.063485
# Batch 98 - Backward pass and optimizer step done
# Batch 99 - Loading data...
# Batch 99 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 99 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 99 - Loss computed: 0.036682
# Batch 99 - Backward pass and optimizer step done
# Batch 100 - Loading data...
# Batch 100 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 100 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 100 - Loss computed: 0.015393
# Batch 100 - Backward pass and optimizer step done
# Epoch 8 Batch 100 Loss: 0.015393
# Batch 101 - Loading data...
# Batch 101 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 101 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 101 - Loss computed: 0.063961
# Batch 101 - Backward pass and optimizer step done
# Batch 102 - Loading data...
# Batch 102 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 102 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 102 - Loss computed: 0.171857
# Batch 102 - Backward pass and optimizer step done
# Batch 103 - Loading data...
# Batch 103 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 103 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 103 - Loss computed: 0.017173
# Batch 103 - Backward pass and optimizer step done
# Batch 104 - Loading data...
# Batch 104 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 104 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 104 - Loss computed: 0.040703
# Batch 104 - Backward pass and optimizer step done
# Batch 105 - Loading data...
# Batch 105 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 105 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 105 - Loss computed: 0.015718
# Batch 105 - Backward pass and optimizer step done
# Batch 106 - Loading data...
# Batch 106 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 106 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 106 - Loss computed: 0.009891
# Batch 106 - Backward pass and optimizer step done
# Batch 107 - Loading data...
# Batch 107 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 107 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 107 - Loss computed: 0.056759
# Batch 107 - Backward pass and optimizer step done
# Batch 108 - Loading data...
# Batch 108 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 108 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 108 - Loss computed: 0.072003
# Batch 108 - Backward pass and optimizer step done
# Batch 109 - Loading data...
# Batch 109 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 109 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 109 - Loss computed: 0.047176
# Batch 109 - Backward pass and optimizer step done
# Batch 110 - Loading data...
# Batch 110 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 110 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 110 - Loss computed: 0.009992
# Batch 110 - Backward pass and optimizer step done
# Epoch 8 Batch 110 Loss: 0.009992
# Batch 111 - Loading data...
# Batch 111 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 111 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 111 - Loss computed: 0.054858
# Batch 111 - Backward pass and optimizer step done
# Batch 112 - Loading data...
# Batch 112 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 112 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 112 - Loss computed: 0.022632
# Batch 112 - Backward pass and optimizer step done
# Batch 113 - Loading data...
# Batch 113 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 113 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 113 - Loss computed: 0.026226
# Batch 113 - Backward pass and optimizer step done
# Batch 114 - Loading data...
# Batch 114 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 114 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 114 - Loss computed: 0.031636
# Batch 114 - Backward pass and optimizer step done
# Batch 115 - Loading data...
# Batch 115 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 115 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 115 - Loss computed: 0.137383
# Batch 115 - Backward pass and optimizer step done
# Batch 116 - Loading data...
# Batch 116 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 116 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 116 - Loss computed: 0.052947
# Batch 116 - Backward pass and optimizer step done
# Batch 117 - Loading data...
# Batch 117 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 117 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 117 - Loss computed: 0.078786
# Batch 117 - Backward pass and optimizer step done
# Batch 118 - Loading data...
# Batch 118 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 118 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 118 - Loss computed: 0.064839
# Batch 118 - Backward pass and optimizer step done
# Batch 119 - Loading data...
# Batch 119 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 119 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 119 - Loss computed: 0.014299
# Batch 119 - Backward pass and optimizer step done
# Batch 120 - Loading data...
# Batch 120 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 120 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 120 - Loss computed: 0.039673
# Batch 120 - Backward pass and optimizer step done
# Epoch 8 Batch 120 Loss: 0.039673
# Batch 121 - Loading data...
# Batch 121 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 121 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 121 - Loss computed: 0.035567
# Batch 121 - Backward pass and optimizer step done
# Batch 122 - Loading data...
# Batch 122 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 122 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 122 - Loss computed: 0.109890
# Batch 122 - Backward pass and optimizer step done
# Batch 123 - Loading data...
# Batch 123 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 123 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 123 - Loss computed: 0.037046
# Batch 123 - Backward pass and optimizer step done
# Batch 124 - Loading data...
# Batch 124 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 124 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 124 - Loss computed: 0.065658
# Batch 124 - Backward pass and optimizer step done
# Batch 125 - Loading data...
# Batch 125 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 125 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 125 - Loss computed: 0.012978
# Batch 125 - Backward pass and optimizer step done
# Batch 126 - Loading data...
# Batch 126 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 126 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 126 - Loss computed: 0.042638
# Batch 126 - Backward pass and optimizer step done
# Batch 127 - Loading data...
# Batch 127 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 127 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 127 - Loss computed: 0.005670
# Batch 127 - Backward pass and optimizer step done
# Batch 128 - Loading data...
# Batch 128 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 128 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 128 - Loss computed: 0.029192
# Batch 128 - Backward pass and optimizer step done
# Batch 129 - Loading data...
# Batch 129 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 129 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 129 - Loss computed: 0.023326
# Batch 129 - Backward pass and optimizer step done
# Batch 130 - Loading data...
# Batch 130 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 130 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 130 - Loss computed: 0.050676
# Batch 130 - Backward pass and optimizer step done
# Epoch 8 Batch 130 Loss: 0.050676
# Batch 131 - Loading data...
# Batch 131 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 131 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 131 - Loss computed: 0.037209
# Batch 131 - Backward pass and optimizer step done
# Batch 132 - Loading data...
# Batch 132 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 132 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 132 - Loss computed: 0.034083
# Batch 132 - Backward pass and optimizer step done
# Batch 133 - Loading data...
# Batch 133 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 133 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 133 - Loss computed: 0.015665
# Batch 133 - Backward pass and optimizer step done
# Batch 134 - Loading data...
# Batch 134 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 134 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 134 - Loss computed: 0.062084
# Batch 134 - Backward pass and optimizer step done
# Batch 135 - Loading data...
# Batch 135 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 135 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 135 - Loss computed: 0.009873
# Batch 135 - Backward pass and optimizer step done
# Batch 136 - Loading data...
# Batch 136 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 136 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 136 - Loss computed: 0.026198
# Batch 136 - Backward pass and optimizer step done
# Batch 137 - Loading data...
# Batch 137 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 137 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 137 - Loss computed: 0.029984
# Batch 137 - Backward pass and optimizer step done
# Batch 138 - Loading data...
# Batch 138 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 138 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 138 - Loss computed: 0.057849
# Batch 138 - Backward pass and optimizer step done
# Batch 139 - Loading data...
# Batch 139 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 139 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 139 - Loss computed: 0.035777
# Batch 139 - Backward pass and optimizer step done
# Batch 140 - Loading data...
# Batch 140 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 140 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 140 - Loss computed: 0.020927
# Batch 140 - Backward pass and optimizer step done
# Epoch 8 Batch 140 Loss: 0.020927
# Batch 141 - Loading data...
# Batch 141 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 141 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 141 - Loss computed: 0.047884
# Batch 141 - Backward pass and optimizer step done
# Batch 142 - Loading data...
# Batch 142 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 142 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 142 - Loss computed: 0.022737
# Batch 142 - Backward pass and optimizer step done
# Batch 143 - Loading data...
# Batch 143 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 143 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 143 - Loss computed: 0.109979
# Batch 143 - Backward pass and optimizer step done
# Batch 144 - Loading data...
# Batch 144 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 144 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 144 - Loss computed: 0.021861
# Batch 144 - Backward pass and optimizer step done
# Batch 145 - Loading data...
# Batch 145 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 145 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 145 - Loss computed: 0.010605
# Batch 145 - Backward pass and optimizer step done
# Batch 146 - Loading data...
# Batch 146 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 146 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 146 - Loss computed: 0.011562
# Batch 146 - Backward pass and optimizer step done
# Batch 147 - Loading data...
# Batch 147 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 147 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 147 - Loss computed: 0.015009
# Batch 147 - Backward pass and optimizer step done
# Batch 148 - Loading data...
# Batch 148 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 148 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 148 - Loss computed: 0.023836
# Batch 148 - Backward pass and optimizer step done
# Batch 149 - Loading data...
# Batch 149 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 149 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 149 - Loss computed: 0.053120
# Batch 149 - Backward pass and optimizer step done
# Batch 150 - Loading data...
# Batch 150 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 150 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 150 - Loss computed: 0.059432
# Batch 150 - Backward pass and optimizer step done
# Epoch 8 Batch 150 Loss: 0.059432
# Batch 151 - Loading data...
# Batch 151 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 151 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 151 - Loss computed: 0.059006
# Batch 151 - Backward pass and optimizer step done
# Batch 152 - Loading data...
# Batch 152 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 152 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 152 - Loss computed: 0.010338
# Batch 152 - Backward pass and optimizer step done
# Batch 153 - Loading data...
# Batch 153 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 153 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 153 - Loss computed: 0.038438
# Batch 153 - Backward pass and optimizer step done
# Batch 154 - Loading data...
# Batch 154 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 154 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 154 - Loss computed: 0.100317
# Batch 154 - Backward pass and optimizer step done
# Batch 155 - Loading data...
# Batch 155 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 155 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 155 - Loss computed: 0.196840
# Batch 155 - Backward pass and optimizer step done
# Batch 156 - Loading data...
# Batch 156 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 156 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 156 - Loss computed: 0.066324
# Batch 156 - Backward pass and optimizer step done
# Batch 157 - Loading data...
# Batch 157 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 157 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 157 - Loss computed: 0.014866
# Batch 157 - Backward pass and optimizer step done
# Batch 158 - Loading data...
# Batch 158 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 158 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 158 - Loss computed: 0.008493
# Batch 158 - Backward pass and optimizer step done
# Batch 159 - Loading data...
# Batch 159 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 159 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 159 - Loss computed: 0.009325
# Batch 159 - Backward pass and optimizer step done
# Batch 160 - Loading data...
# Batch 160 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 160 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 160 - Loss computed: 0.069442
# Batch 160 - Backward pass and optimizer step done
# Epoch 8 Batch 160 Loss: 0.069442
# ...
# Batch 2897 - Backward pass and optimizer step done
# Batch 2898 - Loading data...
# Batch 2898 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2898 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2898 - Loss computed: 0.008338
# Batch 2898 - Backward pass and optimizer step done
# Batch 2899 - Loading data...
# Batch 2899 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2899 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2899 - Loss computed: 0.070469
# Batch 2899 - Backward pass and optimizer step done
# Batch 2900 - Loading data...
# Batch 2900 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2900 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2900 - Loss computed: 0.033648
# Batch 2900 - Backward pass and optimizer step done
# Epoch 8 Batch 2900 Loss: 0.033648
# Batch 2901 - Loading data...
# Batch 2901 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2901 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2901 - Loss computed: 0.069402
# Batch 2901 - Backward pass and optimizer step done
# Batch 2902 - Loading data...
# Batch 2902 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2902 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2902 - Loss computed: 0.055381
# Batch 2902 - Backward pass and optimizer step done
# Batch 2903 - Loading data...
# Batch 2903 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2903 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2903 - Loss computed: 0.019270
# Batch 2903 - Backward pass and optimizer step done
# Batch 2904 - Loading data...
# Batch 2904 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2904 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2904 - Loss computed: 0.042997
# Batch 2904 - Backward pass and optimizer step done
# Batch 2905 - Loading data...
# Batch 2905 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2905 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2905 - Loss computed: 0.016795
# Batch 2905 - Backward pass and optimizer step done
# Batch 2906 - Loading data...
# Batch 2906 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2906 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2906 - Loss computed: 0.015826
# Batch 2906 - Backward pass and optimizer step done
# Batch 2907 - Loading data...
# Batch 2907 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2907 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2907 - Loss computed: 0.099339
# Batch 2907 - Backward pass and optimizer step done
# Batch 2908 - Loading data...
# Batch 2908 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2908 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2908 - Loss computed: 0.046814
# Batch 2908 - Backward pass and optimizer step done
# Batch 2909 - Loading data...
# Batch 2909 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2909 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2909 - Loss computed: 0.033557
# Batch 2909 - Backward pass and optimizer step done
# Batch 2910 - Loading data...
# Batch 2910 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2910 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2910 - Loss computed: 0.043445
# Batch 2910 - Backward pass and optimizer step done
# Epoch 8 Batch 2910 Loss: 0.043445
# Batch 2911 - Loading data...
# Batch 2911 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2911 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2911 - Loss computed: 0.014042
# Batch 2911 - Backward pass and optimizer step done
# Batch 2912 - Loading data...
# Batch 2912 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2912 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2912 - Loss computed: 0.015474
# Batch 2912 - Backward pass and optimizer step done
# Batch 2913 - Loading data...
# Batch 2913 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2913 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2913 - Loss computed: 0.048552
# Batch 2913 - Backward pass and optimizer step done
# Batch 2914 - Loading data...
# Batch 2914 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2914 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2914 - Loss computed: 0.037650
# Batch 2914 - Backward pass and optimizer step done
# Batch 2915 - Loading data...
# Batch 2915 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2915 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2915 - Loss computed: 0.025452
# Batch 2915 - Backward pass and optimizer step done
# Batch 2916 - Loading data...
# Batch 2916 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2916 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2916 - Loss computed: 0.023203
# Batch 2916 - Backward pass and optimizer step done
# Batch 2917 - Loading data...
# Batch 2917 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2917 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2917 - Loss computed: 0.012267
# Batch 2917 - Backward pass and optimizer step done
# Batch 2918 - Loading data...
# Batch 2918 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2918 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2918 - Loss computed: 0.021970
# Batch 2918 - Backward pass and optimizer step done
# Batch 2919 - Loading data...
# Batch 2919 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2919 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2919 - Loss computed: 0.043037
# Batch 2919 - Backward pass and optimizer step done
# Batch 2920 - Loading data...
# Batch 2920 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2920 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2920 - Loss computed: 0.019833
# Batch 2920 - Backward pass and optimizer step done
# Epoch 8 Batch 2920 Loss: 0.019833
# Batch 2921 - Loading data...
# Batch 2921 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2921 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2921 - Loss computed: 0.038859
# Batch 2921 - Backward pass and optimizer step done
# Batch 2922 - Loading data...
# Batch 2922 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2922 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2922 - Loss computed: 0.008705
# Batch 2922 - Backward pass and optimizer step done
# Batch 2923 - Loading data...
# Batch 2923 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2923 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2923 - Loss computed: 0.033912
# Batch 2923 - Backward pass and optimizer step done
# Batch 2924 - Loading data...
# Batch 2924 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2924 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2924 - Loss computed: 0.004391
# Batch 2924 - Backward pass and optimizer step done
# Batch 2925 - Loading data...
# Batch 2925 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2925 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2925 - Loss computed: 0.085200
# Batch 2925 - Backward pass and optimizer step done
# Batch 2926 - Loading data...
# Batch 2926 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2926 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2926 - Loss computed: 0.024638
# Batch 2926 - Backward pass and optimizer step done
# Batch 2927 - Loading data...
# Batch 2927 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2927 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2927 - Loss computed: 0.023938
# Batch 2927 - Backward pass and optimizer step done
# Batch 2928 - Loading data...
# Batch 2928 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2928 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2928 - Loss computed: 0.010716
# Batch 2928 - Backward pass and optimizer step done
# Batch 2929 - Loading data...
# Batch 2929 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2929 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2929 - Loss computed: 0.024166
# Batch 2929 - Backward pass and optimizer step done
# Batch 2930 - Loading data...
# Batch 2930 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2930 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2930 - Loss computed: 0.109685
# Batch 2930 - Backward pass and optimizer step done
# Epoch 8 Batch 2930 Loss: 0.109685
# Batch 2931 - Loading data...
# Batch 2931 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2931 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2931 - Loss computed: 0.101168
# Batch 2931 - Backward pass and optimizer step done
# Batch 2932 - Loading data...
# Batch 2932 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2932 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2932 - Loss computed: 0.076292
# Batch 2932 - Backward pass and optimizer step done
# Batch 2933 - Loading data...
# Batch 2933 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2933 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2933 - Loss computed: 0.077220
# Batch 2933 - Backward pass and optimizer step done
# Batch 2934 - Loading data...
# Batch 2934 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2934 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2934 - Loss computed: 0.020997
# Batch 2934 - Backward pass and optimizer step done
# Batch 2935 - Loading data...
# Batch 2935 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2935 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2935 - Loss computed: 0.035213
# Batch 2935 - Backward pass and optimizer step done
# Batch 2936 - Loading data...
# Batch 2936 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2936 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2936 - Loss computed: 0.042609
# Batch 2936 - Backward pass and optimizer step done
# Batch 2937 - Loading data...
# Batch 2937 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2937 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2937 - Loss computed: 0.100508
# Batch 2937 - Backward pass and optimizer step done
# Batch 2938 - Loading data...
# Batch 2938 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2938 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2938 - Loss computed: 0.042309
# Batch 2938 - Backward pass and optimizer step done
# Batch 2939 - Loading data...
# Batch 2939 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2939 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2939 - Loss computed: 0.030711
# Batch 2939 - Backward pass and optimizer step done
# Batch 2940 - Loading data...
# Batch 2940 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2940 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2940 - Loss computed: 0.040536
# Batch 2940 - Backward pass and optimizer step done
# Epoch 8 Batch 2940 Loss: 0.040536
# Batch 2941 - Loading data...
# Batch 2941 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2941 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2941 - Loss computed: 0.020354
# Batch 2941 - Backward pass and optimizer step done
# Batch 2942 - Loading data...
# Batch 2942 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2942 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2942 - Loss computed: 0.101670
# Batch 2942 - Backward pass and optimizer step done
# Batch 2943 - Loading data...
# Batch 2943 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2943 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2943 - Loss computed: 0.020476
# Batch 2943 - Backward pass and optimizer step done
# Batch 2944 - Loading data...
# Batch 2944 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2944 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2944 - Loss computed: 0.018530
# Batch 2944 - Backward pass and optimizer step done
# Batch 2945 - Loading data...
# Batch 2945 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2945 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2945 - Loss computed: 0.060954
# Batch 2945 - Backward pass and optimizer step done
# Batch 2946 - Loading data...
# Batch 2946 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2946 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2946 - Loss computed: 0.036658
# Batch 2946 - Backward pass and optimizer step done
# Batch 2947 - Loading data...
# Batch 2947 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2947 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2947 - Loss computed: 0.060443
# Batch 2947 - Backward pass and optimizer step done
# Batch 2948 - Loading data...
# Batch 2948 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2948 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2948 - Loss computed: 0.028253
# Batch 2948 - Backward pass and optimizer step done
# Batch 2949 - Loading data...
# Batch 2949 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2949 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2949 - Loss computed: 0.011298
# Batch 2949 - Backward pass and optimizer step done
# Batch 2950 - Loading data...
# Batch 2950 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2950 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2950 - Loss computed: 0.116371
# Batch 2950 - Backward pass and optimizer step done
# Epoch 8 Batch 2950 Loss: 0.116371
# Batch 2951 - Loading data...
# Batch 2951 - Inputs shape: torch.Size([8, 4, 256, 256]), Masks shape: torch.Size([8, 256, 256])
# Batch 2951 - Forward pass done. Outputs shape: torch.Size([8, 4, 256, 256])
# Batch 2951 - Loss computed: 0.207602
# Batch 2951 - Backward pass and optimizer step done
# Epoch 8 Average Loss: 0.049147
# Checkpoint saved: model_epoch8.pt
# Evaluating on entire filtered dataset for metrics...

# %%
import os
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

checkpoint_path = 'C:/Users/sweta/anaconda_projects/non-trivial/performance_bias/iteration_models/model_epoch7.pt'

if os.path.exists(checkpoint_path):
    print(f"Loading checkpoint from {checkpoint_path} ...")
    checkpoint = torch.load(checkpoint_path, map_location=device)
    model.load_state_dict(checkpoint)  # load weights directly
    print("Checkpoint loaded. Model weights restored.")
else:
    print("Checkpoint not found.")
# Out:
# Loading checkpoint from C:/Users/sweta/anaconda_projects/non-trivial/performance_bias/iteration_models/model_epoch7.pt ...
# Checkpoint loaded. Model weights restored.
# C:\Users\sweta\AppData\Local\Temp\ipykernel_10684\4138190591.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
